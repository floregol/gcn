# %%
import pickle as pk
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches
import os

EDS_files = [
'cora_sampling_method=EDS_K_sparsity=100_results.p',
'cora_sampling_method=EDS_K_sparsity=10_results.p',
'cora_sampling_method=EDS_K_sparsity=5_results.p' ]



Greedy_files = [

'cora_sampling_method=Greedy_K_sparsity=100_label_balance=Greedy_noise=0.01_results.p',
'cora_sampling_method=Greedy_K_sparsity=100_label_balance=Greedy_noise=100_results.p',
'cora_sampling_method=Greedy_K_sparsity=100_label_balance=Greedy_noise=1_results.p',
'cora_sampling_method=Greedy_K_sparsity=10_label_balance=Greedy_noise=0.01_results.p',
'cora_sampling_method=Greedy_K_sparsity=10_label_balance=Greedy_noise=100_results.p',
'cora_sampling_method=Greedy_K_sparsity=10_label_balance=Greedy_noise=1_results.p',
'cora_sampling_method=Greedy_K_sparsity=5_label_balance=Greedy_noise=0.01_results.p',
'cora_sampling_method=Greedy_K_sparsity=5_label_balance=Greedy_noise=100_results.p',
'cora_sampling_method=Greedy_K_sparsity=5_label_balance=Greedy_noise=1_results.p']

max_files = ['cora_sampling_method=MaxDegree_maxdegree_results.p']

random_file = ['cora_sampling_method=Random_random_results.p']

# %%
def open_files(files):
    file_content = []
    for file in  files:
        try:
            with open(file, 'rb') as f:
                file_content.append(pk.load(f, encoding='latin1'))
        except Exception as e:
            print(e)
            print("No " + file)
    return file_content
            
eds_results = open_files(EDS_files)
geedy_results = open_files(Greedy_files)
max_results = open_files(max_files)
random_results = open_files(random_file)
# Out:
# [Errno 2] No such file or directory: 'cora_sampling_method=EDS_K_sparsity=100_results.p'
# No cora_sampling_method=EDS_K_sparsity=100_results.p
# [Errno 2] No such file or directory: 'cora_sampling_method=EDS_K_sparsity=10_results.p'
# No cora_sampling_method=EDS_K_sparsity=10_results.p
# [Errno 2] No such file or directory: 'cora_sampling_method=EDS_K_sparsity=5_results.p'
# No cora_sampling_method=EDS_K_sparsity=5_results.p
# [Errno 2] No such file or directory: 'cora_sampling_method=Greedy_K_sparsity=100_label_balance=Greedy_noise=0.01_results.p'
# No cora_sampling_method=Greedy_K_sparsity=100_label_balance=Greedy_noise=0.01_results.p
# [Errno 2] No such file or directory: 'cora_sampling_method=Greedy_K_sparsity=100_label_balance=Greedy_noise=100_results.p'
# No cora_sampling_method=Greedy_K_sparsity=100_label_balance=Greedy_noise=100_results.p
# [Errno 2] No such file or directory: 'cora_sampling_method=Greedy_K_sparsity=100_label_balance=Greedy_noise=1_results.p'
# No cora_sampling_method=Greedy_K_sparsity=100_label_balance=Greedy_noise=1_results.p
# [Errno 2] No such file or directory: 'cora_sampling_method=Greedy_K_sparsity=10_label_balance=Greedy_noise=0.01_results.p'
# No cora_sampling_method=Greedy_K_sparsity=10_label_balance=Greedy_noise=0.01_results.p
# [Errno 2] No such file or directory: 'cora_sampling_method=Greedy_K_sparsity=10_label_balance=Greedy_noise=100_results.p'
# No cora_sampling_method=Greedy_K_sparsity=10_label_balance=Greedy_noise=100_results.p
# [Errno 2] No such file or directory: 'cora_sampling_method=Greedy_K_sparsity=10_label_balance=Greedy_noise=1_results.p'
# No cora_sampling_method=Greedy_K_sparsity=10_label_balance=Greedy_noise=1_results.p
# [Errno 2] No such file or directory: 'cora_sampling_method=Greedy_K_sparsity=5_label_balance=Greedy_noise=0.01_results.p'
# No cora_sampling_method=Greedy_K_sparsity=5_label_balance=Greedy_noise=0.01_results.p
# [Errno 2] No such file or directory: 'cora_sampling_method=Greedy_K_sparsity=5_label_balance=Greedy_noise=100_results.p'
# No cora_sampling_method=Greedy_K_sparsity=5_label_balance=Greedy_noise=100_results.p
# [Errno 2] No such file or directory: 'cora_sampling_method=Greedy_K_sparsity=5_label_balance=Greedy_noise=1_results.p'
# No cora_sampling_method=Greedy_K_sparsity=5_label_balance=Greedy_noise=1_results.p
# [Errno 2] No such file or directory: 'cora_sampling_method=MaxDegree_maxdegree_results.p'
# No cora_sampling_method=MaxDegree_maxdegree_results.p
# [Errno 2] No such file or directory: 'cora_sampling_method=Random_random_results.p'
# No cora_sampling_method=Random_random_results.p

# %%
def results_to_lines(results):
    lines = []
    for result in results:
        line = result['results']
        x = []
        y = []
        var = []
        for point in line:
            x.append(point[1])
            y.append(point[2])
            var.append(point[3])
        lines.append((x,y,var,result['info']))
    return lines

random_ref_line = results_to_lines(random_results)[0]

def plot(title, save_file,lines, label_name = None):
    plt.errorbar(random_ref_line[0],random_ref_line[1],yerr=random_ref_line[2],alpha = 0.7,color = 'r',label="Random sampling",fmt='o-')
    for line in lines:
        if label_name is not None:
            plt.errorbar(line[0],line[1],yerr=line[2],alpha = 0.5,label=label_name+":"+str(line[3][label_name]),fmt='o-')
        else:
            plt.errorbar(line[0],line[1],yerr=line[2],alpha = 0.5,fmt='o-')
    
    plt.plot(23,0.81,'ko')
    plt.xlabel('known labels of training set %')
    plt.ylabel('test accuracy')
   # plt.title(title)
    plt.legend(loc=4)
    plt.grid(True)
    plt.savefig(os.path.join('../report',save_file), bbox_inches="tight", dpi = 300)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-173-69b891d6352f> in <module>
#      13     return lines
#      14
# ---> 15 random_ref_line = results_to_lines(random_results)[0]
#      16
#      17 def plot(title, save_file,lines, label_name = None):
#
# IndexError: list index out of range

# %%
plot("EDS sampling","EDS_sampling.jpg",results_to_lines(eds_results),'K_sparsity')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-174-d6620ae6fd90> in <module>
# ----> 1 plot("EDS sampling","EDS_sampling.jpg",results_to_lines(eds_results),'K_sparsity')
#
# <ipython-input-164-a04392b629cb> in plot(title, save_file, lines, label_name)
#      29     plt.legend(loc=4)
#      30     plt.grid(True)
# ---> 31     plt.savefig(os.path.join('../report',save_file), bbox_inches="tight", dpi = 300)
#      32
#
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     687 def savefig(*args, **kwargs):
#     688     fig = gcf()
# --> 689     res = fig.savefig(*args, **kwargs)
#     690     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     691     return res
#
# ~/.local/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, fname, frameon, transparent, **kwargs)
#    2092             self.set_frameon(frameon)
#    2093
# -> 2094         self.canvas.print_figure(fname, **kwargs)
#    2095
#    2096         if frameon:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2073                     orientation=orientation,
#    2074                     bbox_inches_restore=_bbox_inches_restore,
# -> 2075                     **kwargs)
#    2076             finally:
#    2077                 if bbox_inches and restore_bbox:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_jpg(self, filename_or_obj, dryrun, *args, **kwargs)
#     576                 options['dpi'] = (options['dpi'], options['dpi'])
#     577
# --> 578             return background.save(filename_or_obj, format='jpeg', **options)
#     579         print_jpeg = print_jpg
#     580
#
# /usr/lib/python3/dist-packages/PIL/Image.py in save(self, fp, format, **params)
#    1930                 # Open also for reading ("+"), because TIFF save_all
#    1931                 # writer needs to go back and edit the written data.
# -> 1932                 fp = builtins.open(filename, "w+b")
#    1933
#    1934         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../report/EDS_sampling.jpg'

# %%
plot("Greedy sampling, K sparsity = 100 ","Greedy_K100_sampling.jpg",results_to_lines(geedy_results[0:3]),'noise')

# %%
plot("Greedy sampling, K sparsity = 10 ","Greedy_K10_sampling.jpg",results_to_lines(geedy_results[3:6]),'noise')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-175-fb0216ee7e4f> in <module>
# ----> 1 plot("Greedy sampling, K sparsity = 10 ","Greedy_K10_sampling.jpg",results_to_lines(geedy_results[3:6]),'noise')
#
# <ipython-input-164-a04392b629cb> in plot(title, save_file, lines, label_name)
#      29     plt.legend(loc=4)
#      30     plt.grid(True)
# ---> 31     plt.savefig(os.path.join('../report',save_file), bbox_inches="tight", dpi = 300)
#      32
#
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     687 def savefig(*args, **kwargs):
#     688     fig = gcf()
# --> 689     res = fig.savefig(*args, **kwargs)
#     690     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     691     return res
#
# ~/.local/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, fname, frameon, transparent, **kwargs)
#    2092             self.set_frameon(frameon)
#    2093
# -> 2094         self.canvas.print_figure(fname, **kwargs)
#    2095
#    2096         if frameon:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2073                     orientation=orientation,
#    2074                     bbox_inches_restore=_bbox_inches_restore,
# -> 2075                     **kwargs)
#    2076             finally:
#    2077                 if bbox_inches and restore_bbox:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_jpg(self, filename_or_obj, dryrun, *args, **kwargs)
#     576                 options['dpi'] = (options['dpi'], options['dpi'])
#     577
# --> 578             return background.save(filename_or_obj, format='jpeg', **options)
#     579         print_jpeg = print_jpg
#     580
#
# /usr/lib/python3/dist-packages/PIL/Image.py in save(self, fp, format, **params)
#    1930                 # Open also for reading ("+"), because TIFF save_all
#    1931                 # writer needs to go back and edit the written data.
# -> 1932                 fp = builtins.open(filename, "w+b")
#    1933
#    1934         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../report/Greedy_K10_sampling.jpg'

# %%
plot("Greedy sampling, K sparsity = 5 ","Greedy_K5_sampling.jpg",results_to_lines(geedy_results[6:9]),'noise')

# %%
plot("Max degree sampling,","Max_sampling.jpg",results_to_lines(max_results))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-176-063de1668f3a> in <module>
# ----> 1 plot("Max degree sampling,","Max_sampling.jpg",results_to_lines(max_results))
#
# <ipython-input-164-a04392b629cb> in plot(title, save_file, lines, label_name)
#      29     plt.legend(loc=4)
#      30     plt.grid(True)
# ---> 31     plt.savefig(os.path.join('../report',save_file), bbox_inches="tight", dpi = 300)
#      32
#
# ~/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     687 def savefig(*args, **kwargs):
#     688     fig = gcf()
# --> 689     res = fig.savefig(*args, **kwargs)
#     690     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     691     return res
#
# ~/.local/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, fname, frameon, transparent, **kwargs)
#    2092             self.set_frameon(frameon)
#    2093
# -> 2094         self.canvas.print_figure(fname, **kwargs)
#    2095
#    2096         if frameon:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2073                     orientation=orientation,
#    2074                     bbox_inches_restore=_bbox_inches_restore,
# -> 2075                     **kwargs)
#    2076             finally:
#    2077                 if bbox_inches and restore_bbox:
#
# ~/.local/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in print_jpg(self, filename_or_obj, dryrun, *args, **kwargs)
#     576                 options['dpi'] = (options['dpi'], options['dpi'])
#     577
# --> 578             return background.save(filename_or_obj, format='jpeg', **options)
#     579         print_jpeg = print_jpg
#     580
#
# /usr/lib/python3/dist-packages/PIL/Image.py in save(self, fp, format, **params)
#    1930                 # Open also for reading ("+"), because TIFF save_all
#    1931                 # writer needs to go back and edit the written data.
# -> 1932                 fp = builtins.open(filename, "w+b")
#    1933
#    1934         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../report/Max_sampling.jpg'

# %%
# Out:
# /home/floregol
